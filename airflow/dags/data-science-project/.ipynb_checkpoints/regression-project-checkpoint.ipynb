# %% [markdown]
# # Importando as bibliotecas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %matplotlib inline

# %% [markdown]
# ## Etapas do projeto
# - Coleta de dados
# - Análise de dados
# - Criação de modelos
# - Validação de modelos
# - Apresentação dos resultados

# %% [markdown]
# #### Parametros

# %%
dataset = "./data/ecomerce.csv"
model = "./model/"
test_size_ = 0.3
n_estimators = 100,
max_depth = 10,

# %% [markdown]
# #### Leitura dos dados

# %%
clientes = pd.read_csv(dataset)

# %%
clientes.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
clientes.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# - Qual a relação do cara que passa mais tempo no site em relação ao valor gasto anual?

# %%
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - Qual a relação do cara que passa mais tempo no APP em relação ao valor gasto anual?

# %%
sns.jointplot(x='Time on App', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - As pessoas que usam o aplicativo elas são clientes a mais tempo ou não?

# %%
sns.jointplot(x='Time on App', y='Length of Membership', data=clientes, kind='hex')

# %% [markdown]
# - Quais variáveis conseguimos explicar ou que tem maior impacto no quanto uma pessoa gasta no ano?

# %%
sns.pairplot(clientes)

# %% [markdown]
# - Como ficaria um modelo linear usando o Tempo de App em relação ao valor gasto?

# %%
sns.lmplot(x='Time on App', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - Como ficaria um modelo linear usando o Tempo de Membro em relação ao valor gasto?

# %%
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# ## 3. Criação de um Modelo com todas as variáveis

# %% [markdown]
# - Separa quem meu X e meu y

# %%
clientes.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
y = clientes['Yearly Amount Spent']

# %%
X = clientes[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]

# %% [markdown]
# - Dividir meu conjunto em treino e teste usando sckit learning

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=test_size_,random_state=42)

# %%
y_train.shape
# Out:
# (350,)

# %%
y_test.shape
# Out:
# (150,)

# %% [markdown]
# - Criar um modelo de regressão linear usando sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(
            n_estimators = n_estimators,
            max_depth = max_depth,
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# - Para validar o modelo no conjunto de teste, você precisa utilizar o método predict()

# %%
ỹ = rf.predict(X_test)

# %%
ỹ
# Out:
# array([408.63937196, 542.75044451, 468.39277485, 508.3833469 ,
#        422.00528837, 562.25243451, 525.01034614, 502.71529655,
#        411.34732382, 453.84406596, 440.98388238, 419.37864452,
#        437.43713317, 541.15196795, 425.18092204, 422.85858144,
#        570.17445356, 479.13688498, 454.66078209, 471.45664217,
#        467.11255559, 521.43218156, 513.66724548, 624.04009398,
#        433.40366517, 501.0275102 , 542.24540958, 559.66667048,
#        398.29043904, 350.8587937 , 547.90758343, 483.8215735 ,
#        501.32588402, 309.49995476, 516.34929172, 479.57073933,
#        519.86399093, 437.02708099, 452.29772617, 473.7026532 ,
#        493.3601945 , 416.43198545, 509.62879772, 495.29910405,
#        489.34190112, 542.50876317, 580.2659016 , 524.38031441,
#        325.17933637, 444.21427488, 423.04215866, 482.57889802,
#        581.82099039, 605.43221946, 571.49353051, 500.80616707,
#        392.24412802, 416.05351372, 562.4532542 , 504.13794269,
#        511.92707622, 383.50644551, 475.18036589, 482.25260968,
#        471.37707909, 549.80973196, 419.48689244, 579.93075247,
#        443.09602451, 498.61832953, 529.33290419, 561.95152837,
#        614.68798452, 510.75096785, 412.80216759, 490.72906297,
#        472.96263035, 437.07921251, 449.79504299, 512.35874156,
#        552.54726575, 614.73806605, 505.48490136, 641.9341596 ,
#        531.37642234, 451.19548206, 521.67067979, 551.64884288,
#        366.48971914, 517.19961785, 541.56952674, 496.66867002,
#        411.67844858, 569.12981355, 461.63133614, 562.13075349,
#        481.00288702, 447.56698786, 418.21304219, 476.00121133,
#        529.3702725 , 394.62032734, 594.70730614, 498.02454511,
#        396.49259062, 524.58009865, 506.10515844, 441.97264781,
#        532.38185883, 435.65214062, 420.52833671, 450.53956807,
#        458.38404227, 448.71856432, 666.0065177 , 554.0730348 ,
#        627.68965637, 413.41624069, 559.11602965, 571.71874194,
#        531.0346177 , 539.15781736, 386.37084222, 664.3963943 ,
#        532.55962434, 461.85328329, 447.60301323, 407.74274838,
#        523.887306  , 441.17864431, 456.45613008, 419.74131471,
#        421.23021004, 623.51133746, 481.05836598, 466.29901792,
#        541.39914955, 707.9772053 , 422.49061568, 552.82393197,
#        564.50015806, 413.4906959 , 389.48829302, 518.65769922,
#        509.11524911, 538.68533232, 511.59594098, 509.9024213 ,
#        517.2874625 , 545.31980765])

# %% [markdown]
# ** Crie um diagrama de dispersão (scatterplot) dos valores reais de teste em relação aos valores preditos. **

# %%
plt.scatter(y_test, ỹ)
plt.xlabel('y real')
plt.ylabel('ỹ predito')
# Out:
# Text(0, 0.5, 'ỹ predito')

# %% [markdown]
# #### Imprime os parametros do modelo.

# %%
print(rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## 4. Avaliando o Modelo

# %%
sns.displot(clientes, x="Yearly Amount Spent")
plt.tight_layout()

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, ỹ))
print('MSE:', metrics.mean_squared_error(y_test, ỹ))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, ỹ)))
print('R2:', metrics.r2_score(y_test,ỹ))
# Out:
# MAE: 13.905263363384044
# MSE: 309.8312804318859
# RMSE: 17.602024895786446
# R2: 0.9429797851751089

# %%
metricas = pd.DataFrame(data=None,columns=["MAE","MSE","RMSE","R2"])

# %%
metricas['MAE'] = [metrics.mean_absolute_error(y_test,ỹ)]
metricas['MSE'] = [metrics.mean_squared_error(y_test,ỹ)]
metricas['RMSE'] = [np.sqrt(metrics.mean_squared_error(y_test, ỹ))]
metricas['R2'] = [metrics.r2_score(y_test,ỹ)]

# %%
metricas.head()
# Out:
#          MAE        MSE       RMSE       R2
# 0  13.905263  309.83128  17.602025  0.94298

# %% [markdown]
# ## Exportando o modelo.

# %%
joblib.dump(rf,model+"model.joblib")
# Out:
# ['./model/model.joblib']
